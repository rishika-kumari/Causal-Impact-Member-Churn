# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../../data/processed/merged_panel_clean_data.csv")
df["zeit"] = df["jahr"].astype(str) + "Q" + df["quartal"].astype(str)

def plot_fund_size_over_time():
    sns.lineplot(data=df, x="zeit", y="versicherte", hue="kasse_clean", legend=False)
    plt.title("Fund Size Over Time")
    plt.xticks(rotation=90)
    plt.show()

def plot_morbidity_over_time():
    sns.lineplot(data=df, x="zeit", y="morbidity_index", hue="kasse_clean", legend=False)
    plt.title("Morbidity Index Over Time")
    plt.xticks(rotation=90)
    plt.show()

if __name__ == "__main__":
    plot_fund_size_over_time()
    plot_morbidity_over_time()
# Out:
# /var/folders/kk/mr4t4jss0v3fbs24nvk11mdh0000gn/T/ipykernel_1364/3356206650.py:5: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/processed/merged_panel_clean_data.csv")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 22
#      20 if __name__ == "__main__":
#      21     plot_fund_size_over_time()
# ---> 22     plot_morbidity_over_time()
#
# Cell In[2], line 15, in plot_morbidity_over_time()
#      14 def plot_morbidity_over_time():
# ---> 15     sns.lineplot(data=df, x="zeit", y="morbidity_index", hue="kasse_clean", legend=False)
#      16     plt.title("Morbidity Index Over Time")
#      17     plt.xticks(rotation=90)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/relational.py:508, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     505 if not p.has_xy_data:
#     506     return ax
# --> 508 p._attach(ax)
#     510 # Other functions have color as an explicit param,
#     511 # and we should probably do that here too
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/_base.py:1135, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1133                 order = None
#    1134             seed_data = categorical_order(seed_data, order)
# -> 1135         converter.update_units(seed_data)
#    1137 # -- Set numerical axis scales
#    1138
#    1139 # First unpack the log_scale argument
#    1140 if log_scale is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
